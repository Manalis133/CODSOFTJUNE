# %% [markdown]
# <a href="https://colab.research.google.com/github/Manalis133/CODSOFTJUNE/blob/main/Credit_Card_Fraud_Detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
data = pd.read_csv('/content/creditcard.csv')

# %%
print(data.head())
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
print(data.tail())
# Out:
#       Time        V1        V2        V3        V4        V5        V6  \
# 5969  6634 -1.611463  0.190648  0.901715  1.531254 -1.535865  0.799245
# 5970  6635 -1.420272  1.449354  1.320110 -1.894320  0.913695  0.454601
# 5971  6637 -1.206696  0.284728  2.152053 -2.850437 -0.437285 -0.238376
# 5972  6644  1.067611  0.091006 -0.153917  0.704233  0.113894 -0.826866
# 5973  6645 -0.535272 -0.132299  2.180041  1.018303 -1.498819  0.529570
#
#             V7        V8        V9  ...       V21       V22       V23  \
# 5969  1.513786  0.495829  0.200390  ...  0.211223  0.007477  1.026272
# 5970  0.894179 -0.385450  2.433841  ... -0.529027 -0.368394 -0.247773
# 5971 -0.333341  0.334679  2.870542  ...  0.039460  0.464476 -0.457193
# 5972  0.567690 -0.464181  0.957295  ... -0.476723 -1.410090 -0.037550
# 5973  0.420147  0.045445  1.543919  ...       NaN       NaN       NaN
#
#            V24       V25       V26       V27       V28  Amount  Class
# ...

# %%
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5974 entries, 0 to 5973
# Data columns (total 31 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Time    5974 non-null   int64
#  1   V1      5974 non-null   float64
#  2   V2      5974 non-null   float64
#  3   V3      5974 non-null   float64
#  4   V4      5974 non-null   float64
#  5   V5      5974 non-null   float64
#  6   V6      5974 non-null   float64
#  7   V7      5974 non-null   float64
#  8   V8      5974 non-null   float64
#  9   V9      5974 non-null   float64
#  10  V10     5974 non-null   float64
#  11  V11     5974 non-null   float64
#  12  V12     5974 non-null   float64
#  13  V13     5974 non-null   float64
#  14  V14     5974 non-null   float64
#  15  V15     5974 non-null   float64
#  16  V16     5974 non-null   float64
#  17  V17     5974 non-null   float64
#  18  V18     5973 non-null   float64
#  19  V19     5973 non-null   float64
# ...

# %%
print(data['Class'].value_counts())
# Out:
# 0.0    5970
# 1.0       3
# Name: Class, dtype: int64

# %%
legit = data[data['Class'] == 0]
fraud = data[data['Class'] == 1]

# %%
print(legit.shape)
print(fraud.shape)
# Out:
# (5970, 31)
# (3, 31)

# %%
legit.Amount.describe()
# Out:
# count    5970.000000
# mean       64.965707
# std       192.429839
# min         0.000000
# 25%         4.450000
# 50%        15.620000
# 75%        56.485000
# max      7712.430000
# Name: Amount, dtype: float64

# %%
fraud.Amount.describe()
# Out:
# count      3.000000
# mean     256.310000
# std      264.880121
# min        0.000000
# 25%      119.965000
# 50%      239.930000
# 75%      384.465000
# max      529.000000
# Name: Amount, dtype: float64

# %%
data.groupby('Class').mean()
# Out:
#              Time        V1        V2        V3        V4        V5        V6  \
# Class
# 0.0    2677.40201 -0.264965  0.285625  0.844580  0.102656  0.000958  0.195420
# 1.0    1780.00000 -2.553039  0.184644 -0.293711  2.872264  0.005330 -0.855718
#
#              V7        V8        V9  ...       V20       V21       V22  \
# Class                                ...
# 0.0    0.018542 -0.039195  0.397472  ...  0.055426 -0.043268 -0.161540
# 1.0   -0.549831  0.308239 -1.093098  ...  0.599742  0.294921 -0.177321
#
#             V23       V24       V25       V26       V27       V28      Amount
# Class
# 0.0   -0.036683  0.028985  0.089890 -0.040132  0.025238  0.006163   64.965707
# 1.0    0.361160 -0.020311  0.056068 -0.170050  0.015979 -0.086847  256.310000
#
# [2 rows x 30 columns]

# %%
legit_sample = legit.sample(n=389, random_state=42)

# %%
new_data= pd.concat([legit_sample, fraud], axis=0)
new_data.head()
# Out:
#       Time        V1        V2        V3        V4        V5        V6  \
# 3753  3247 -1.356564  0.630977  2.072964  0.795754 -0.345744  0.202577
# 812    619  1.121028 -0.626311  0.105123  0.634477  1.219799  4.700368
# 1602  1247  1.055550 -0.282119 -0.074789  0.251727  0.833534  2.307399
# 5732  6047 -0.344878  1.195036  1.425267  0.273839  0.059852 -0.955118
# 4686  4111 -1.313887  0.331859  0.299060 -0.823644  3.523227  2.999996
#
#             V7        V8        V9  ...       V21       V22       V23  \
# 3753 -0.577751  0.706688 -0.187125  ...  0.312536  0.748449 -0.340607
# 812  -1.488651  1.287611  1.498948  ... -0.176767 -0.198571 -0.119171
# 1602 -0.488179  0.699448  0.317465  ... -0.132353 -0.127154 -0.025559
# 5732  0.577690 -0.122063  0.973604  ... -0.419675 -0.920886  0.005982
# 4686 -0.039735  0.776845  0.594761  ... -0.097425 -0.362875 -0.377750
#
#            V24       V25       V26       V27       V28  Amount  Class
# ...

# %%
new_data.tail()
# Out:
#       Time        V1        V2        V3        V4        V5        V6  \
# 5185  4942  1.054885 -0.558337 -0.522328 -0.357718 -0.268561 -0.600676
# 1163   908  1.101281  0.016159  1.421409  1.263577 -0.922315  0.026539
# 541    406 -2.312227  1.951992 -1.609851  3.997906 -0.522188 -1.426545
# 623    472 -3.043541 -3.157307  1.088463  2.288644  1.359805 -1.064823
# 4920  4462 -2.303350  1.759247 -0.359745  2.330243 -0.821628 -0.075788
#
#             V7        V8        V9  ...       V21       V22       V23  \
# 5185 -0.057186 -0.271195 -0.228717  ...  0.216115  0.506129 -0.320170
# 1163 -0.583022  0.158607  0.444008  ...  0.014489  0.273573 -0.003542
# 541  -2.537387  1.391657 -2.770089  ...  0.517232 -0.035049 -0.465211
# 623   0.325574 -0.067794 -0.270953  ...  0.661696  0.435477  1.375966
# 4920  0.562320 -0.399147 -0.238253  ... -0.294166 -0.932391  0.172726
#
#            V24       V25       V26       V27       V28  Amount  Class
# ...

# %%
new_data['Class'].value_counts()
# Out:
# 0.0    389
# 1.0      3
# Name: Class, dtype: int64

# %%
new_data.groupby('Class').mean()
# Out:
#               Time        V1        V2        V3        V4        V5  \
# Class
# 0.0    2595.670951 -0.221757  0.226208  0.937917  0.076468  0.021202
# 1.0    1780.000000 -2.553039  0.184644 -0.293711  2.872264  0.005330
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0.0    0.263096 -0.000862  0.003671  0.389538  ...  0.071331 -0.035630
# 1.0   -0.855718 -0.549831  0.308239 -1.093098  ...  0.599742  0.294921
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0.0   -0.156645 -0.027848  0.104971  0.081830 -0.067831  0.017648  0.005146
# 1.0   -0.177321  0.361160 -0.020311  0.056068 -0.170050  0.015979 -0.086847
#
#            Amount
# Class
# 0.0     62.714602
# 1.0    256.310000
#
# [2 rows x 30 columns]

# %%
X = new_data.drop('Class', axis=1)
Y = new_data['Class']

print(X)
# Out:
#       Time        V1        V2        V3        V4        V5        V6  \
# 3753  3247 -1.356564  0.630977  2.072964  0.795754 -0.345744  0.202577
# 812    619  1.121028 -0.626311  0.105123  0.634477  1.219799  4.700368
# 1602  1247  1.055550 -0.282119 -0.074789  0.251727  0.833534  2.307399
# 5732  6047 -0.344878  1.195036  1.425267  0.273839  0.059852 -0.955118
# 4686  4111 -1.313887  0.331859  0.299060 -0.823644  3.523227  2.999996
# ...    ...       ...       ...       ...       ...       ...       ...
# 5185  4942  1.054885 -0.558337 -0.522328 -0.357718 -0.268561 -0.600676
# 1163   908  1.101281  0.016159  1.421409  1.263577 -0.922315  0.026539
# 541    406 -2.312227  1.951992 -1.609851  3.997906 -0.522188 -1.426545
# 623    472 -3.043541 -3.157307  1.088463  2.288644  1.359805 -1.064823
# 4920  4462 -2.303350  1.759247 -0.359745  2.330243 -0.821628 -0.075788
#
#             V7        V8        V9  ...       V20       V21       V22  \
# ...

# %%
print(Y)
# Out:
# 3753    0.0
# 812     0.0
# 1602    0.0
# 5732    0.0
# 4686    0.0
#        ...
# 5185    0.0
# 1163    0.0
# 541     1.0
# 623     1.0
# 4920    1.0
# Name: Class, Length: 392, dtype: float64

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, stratify=Y, random_state=2)

# %%
print(X.shape, X_train.shape, X_test.shape)
# Out:
# (392, 30) (313, 30) (79, 30)

# %%
model = LogisticRegression(max_iter=1000, random_state=42)

# %%
model.fit(X_train, Y_train)
# Out:
# LogisticRegression(max_iter=1000, random_state=42)

# %%
X_train_prediction = model.predict(X_train)
training_data_accuracy = accuracy_score(X_train_prediction, Y_train)

# %%
print('Accuracy on Training data : ', training_data_accuracy)
# Out:
# Accuracy on Training data :  1.0

# %%
X_test_prediction = model.predict(X_test)
test_data_accuracy = accuracy_score(X_test_prediction, Y_test)

# %%
print('Accuracy score on Test Data : ', test_data_accuracy)
# Out:
# Accuracy score on Test Data :  0.9873417721518988
